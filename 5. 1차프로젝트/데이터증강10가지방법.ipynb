# %%
import os
import numpy as np
from PIL import Image, ImageEnhance, ImageOps, ImageFilter
import random

def blend_with_green(image, alpha=0.5):
    image = image.convert('RGB')
    np_img = np.array(image)
    green_img = np.zeros_like(np_img)
    green_img[:, :, 1] = 255  # Green 채널만 255로 설정
    blended_img = np_img * (1 - alpha) + green_img * alpha
    blended_img = blended_img.astype(np.uint8)
    blended_image = Image.fromarray(blended_img, 'RGB')
    return blended_image

def flip_left_right(image):
    return image.transpose(Image.FLIP_LEFT_RIGHT)

def flip_top_bottom(image):
    return image.transpose(Image.FLIP_TOP_BOTTOM)

def rotate_image(image, angle=90):
    return image.rotate(angle)

def adjust_brightness(image, factor=1.5):
    enhancer = ImageEnhance.Brightness(image)
    return enhancer.enhance(factor)

def adjust_contrast(image, factor=1.5):
    enhancer = ImageEnhance.Contrast(image)
    return enhancer.enhance(factor)

def adjust_saturation(image, factor=1.5):
    enhancer = ImageEnhance.Color(image)
    return enhancer.enhance(factor)

def random_crop(image, crop_size=(100, 100)):
    width, height = image.size
    crop_width, crop_height = crop_size

    if crop_width > width or crop_height > height:
        raise ValueError(f"Crop size {crop_size} is larger than image size {(width, height)}")

    left = random.randint(0, width - crop_width)
    top = random.randint(0, height - crop_height)
    right = left + crop_width
    bottom = top + crop_height
    return image.crop((left, top, right, bottom)).resize((width, height))

def add_noise(image):
    np_img = np.array(image)
    noise = np.random.normal(0, 25, np_img.shape)
    noisy_img = np_img + noise
    noisy_img = np.clip(noisy_img, 0, 255).astype(np.uint8)
    noisy_image = Image.fromarray(noisy_img, 'RGB')
    return noisy_image

def gaussian_blur(image, radius=2):
    return image.filter(ImageFilter.GaussianBlur(radius))

def process_images(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    transformations = [
        ('GreenBlend_', blend_with_green),
        ('FlipLR_', flip_left_right),
        ('FlipTB_', flip_top_bottom),
        ('Rotate_', lambda img: rotate_image(img, angle=90)),
        ('Brightness_', lambda img: adjust_brightness(img, factor=1.5)),
        ('Contrast_', lambda img: adjust_contrast(img, factor=1.5)),
        ('Saturation_', lambda img: adjust_saturation(img, factor=1.5)),
        ('Crop_', lambda img: random_crop(img, crop_size=(50, 50))),  # 크기 조정
        ('Noise_', add_noise),
        ('Blur_', lambda img: gaussian_blur(img, radius=2))
    ]

    for filename in os.listdir(input_folder):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            for prefix, transform in transformations:
                transformed_image = transform(image)
                output_filename = prefix + filename
                output_path = os.path.join(output_folder, output_filename)
                transformed_image.save(output_path)
                print(f"Processed {output_filename}")

# 사용자 경로 설정
input_folder = 'C:/Users/USER/Desktop/new그립플라이어'
output_folder = 'C:/Users/USER/Desktop/output1'

process_images(input_folder, output_folder)
# Out:
# Processed GreenBlend_화면 캡처 2024-07-22 151858.jpg
# Processed FlipLR_화면 캡처 2024-07-22 151858.jpg
# Processed FlipTB_화면 캡처 2024-07-22 151858.jpg
# Processed Rotate_화면 캡처 2024-07-22 151858.jpg
# Processed Brightness_화면 캡처 2024-07-22 151858.jpg
# Processed Contrast_화면 캡처 2024-07-22 151858.jpg
# Processed Saturation_화면 캡처 2024-07-22 151858.jpg
# Processed Crop_화면 캡처 2024-07-22 151858.jpg
# Processed Noise_화면 캡처 2024-07-22 151858.jpg
# Processed Blur_화면 캡처 2024-07-22 151858.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 151913.jpg
# Processed FlipLR_화면 캡처 2024-07-22 151913.jpg
# Processed FlipTB_화면 캡처 2024-07-22 151913.jpg
# Processed Rotate_화면 캡처 2024-07-22 151913.jpg
# Processed Brightness_화면 캡처 2024-07-22 151913.jpg
# Processed Contrast_화면 캡처 2024-07-22 151913.jpg
# Processed Saturation_화면 캡처 2024-07-22 151913.jpg
# Processed Crop_화면 캡처 2024-07-22 151913.jpg
# Processed Noise_화면 캡처 2024-07-22 151913.jpg
# Processed Blur_화면 캡처 2024-07-22 151913.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 151933.jpg
# Processed FlipLR_화면 캡처 2024-07-22 151933.jpg
# Processed FlipTB_화면 캡처 2024-07-22 151933.jpg
# Processed Rotate_화면 캡처 2024-07-22 151933.jpg
# Processed Brightness_화면 캡처 2024-07-22 151933.jpg
# Processed Contrast_화면 캡처 2024-07-22 151933.jpg
# Processed Saturation_화면 캡처 2024-07-22 151933.jpg
# Processed Crop_화면 캡처 2024-07-22 151933.jpg
# Processed Noise_화면 캡처 2024-07-22 151933.jpg
# Processed Blur_화면 캡처 2024-07-22 151933.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 151949.jpg
# Processed FlipLR_화면 캡처 2024-07-22 151949.jpg
# Processed FlipTB_화면 캡처 2024-07-22 151949.jpg
# Processed Rotate_화면 캡처 2024-07-22 151949.jpg
# Processed Brightness_화면 캡처 2024-07-22 151949.jpg
# Processed Contrast_화면 캡처 2024-07-22 151949.jpg
# Processed Saturation_화면 캡처 2024-07-22 151949.jpg
# Processed Crop_화면 캡처 2024-07-22 151949.jpg
# Processed Noise_화면 캡처 2024-07-22 151949.jpg
# Processed Blur_화면 캡처 2024-07-22 151949.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152005.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152005.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152005.jpg
# Processed Rotate_화면 캡처 2024-07-22 152005.jpg
# Processed Brightness_화면 캡처 2024-07-22 152005.jpg
# Processed Contrast_화면 캡처 2024-07-22 152005.jpg
# Processed Saturation_화면 캡처 2024-07-22 152005.jpg
# Processed Crop_화면 캡처 2024-07-22 152005.jpg
# Processed Noise_화면 캡처 2024-07-22 152005.jpg
# Processed Blur_화면 캡처 2024-07-22 152005.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152025.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152025.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152025.jpg
# Processed Rotate_화면 캡처 2024-07-22 152025.jpg
# Processed Brightness_화면 캡처 2024-07-22 152025.jpg
# Processed Contrast_화면 캡처 2024-07-22 152025.jpg
# Processed Saturation_화면 캡처 2024-07-22 152025.jpg
# Processed Crop_화면 캡처 2024-07-22 152025.jpg
# Processed Noise_화면 캡처 2024-07-22 152025.jpg
# Processed Blur_화면 캡처 2024-07-22 152025.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152041.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152041.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152041.jpg
# Processed Rotate_화면 캡처 2024-07-22 152041.jpg
# Processed Brightness_화면 캡처 2024-07-22 152041.jpg
# Processed Contrast_화면 캡처 2024-07-22 152041.jpg
# Processed Saturation_화면 캡처 2024-07-22 152041.jpg
# Processed Crop_화면 캡처 2024-07-22 152041.jpg
# Processed Noise_화면 캡처 2024-07-22 152041.jpg
# Processed Blur_화면 캡처 2024-07-22 152041.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152059.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152059.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152059.jpg
# Processed Rotate_화면 캡처 2024-07-22 152059.jpg
# Processed Brightness_화면 캡처 2024-07-22 152059.jpg
# Processed Contrast_화면 캡처 2024-07-22 152059.jpg
# Processed Saturation_화면 캡처 2024-07-22 152059.jpg
# Processed Crop_화면 캡처 2024-07-22 152059.jpg
# Processed Noise_화면 캡처 2024-07-22 152059.jpg
# Processed Blur_화면 캡처 2024-07-22 152059.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152113.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152113.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152113.jpg
# Processed Rotate_화면 캡처 2024-07-22 152113.jpg
# Processed Brightness_화면 캡처 2024-07-22 152113.jpg
# Processed Contrast_화면 캡처 2024-07-22 152113.jpg
# Processed Saturation_화면 캡처 2024-07-22 152113.jpg
# Processed Crop_화면 캡처 2024-07-22 152113.jpg
# Processed Noise_화면 캡처 2024-07-22 152113.jpg
# Processed Blur_화면 캡처 2024-07-22 152113.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152132.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152132.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152132.jpg
# Processed Rotate_화면 캡처 2024-07-22 152132.jpg
# Processed Brightness_화면 캡처 2024-07-22 152132.jpg
# Processed Contrast_화면 캡처 2024-07-22 152132.jpg
# Processed Saturation_화면 캡처 2024-07-22 152132.jpg
# Processed Crop_화면 캡처 2024-07-22 152132.jpg
# Processed Noise_화면 캡처 2024-07-22 152132.jpg
# Processed Blur_화면 캡처 2024-07-22 152132.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152143.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152143.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152143.jpg
# Processed Rotate_화면 캡처 2024-07-22 152143.jpg
# Processed Brightness_화면 캡처 2024-07-22 152143.jpg
# Processed Contrast_화면 캡처 2024-07-22 152143.jpg
# Processed Saturation_화면 캡처 2024-07-22 152143.jpg
# Processed Crop_화면 캡처 2024-07-22 152143.jpg
# Processed Noise_화면 캡처 2024-07-22 152143.jpg
# Processed Blur_화면 캡처 2024-07-22 152143.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152156.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152156.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152156.jpg
# Processed Rotate_화면 캡처 2024-07-22 152156.jpg
# Processed Brightness_화면 캡처 2024-07-22 152156.jpg
# Processed Contrast_화면 캡처 2024-07-22 152156.jpg
# Processed Saturation_화면 캡처 2024-07-22 152156.jpg
# Processed Crop_화면 캡처 2024-07-22 152156.jpg
# Processed Noise_화면 캡처 2024-07-22 152156.jpg
# Processed Blur_화면 캡처 2024-07-22 152156.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152207.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152207.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152207.jpg
# Processed Rotate_화면 캡처 2024-07-22 152207.jpg
# Processed Brightness_화면 캡처 2024-07-22 152207.jpg
# Processed Contrast_화면 캡처 2024-07-22 152207.jpg
# Processed Saturation_화면 캡처 2024-07-22 152207.jpg
# Processed Crop_화면 캡처 2024-07-22 152207.jpg
# Processed Noise_화면 캡처 2024-07-22 152207.jpg
# Processed Blur_화면 캡처 2024-07-22 152207.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152221.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152221.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152221.jpg
# Processed Rotate_화면 캡처 2024-07-22 152221.jpg
# Processed Brightness_화면 캡처 2024-07-22 152221.jpg
# Processed Contrast_화면 캡처 2024-07-22 152221.jpg
# Processed Saturation_화면 캡처 2024-07-22 152221.jpg
# Processed Crop_화면 캡처 2024-07-22 152221.jpg
# Processed Noise_화면 캡처 2024-07-22 152221.jpg
# Processed Blur_화면 캡처 2024-07-22 152221.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152232.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152232.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152232.jpg
# Processed Rotate_화면 캡처 2024-07-22 152232.jpg
# Processed Brightness_화면 캡처 2024-07-22 152232.jpg
# Processed Contrast_화면 캡처 2024-07-22 152232.jpg
# Processed Saturation_화면 캡처 2024-07-22 152232.jpg
# Processed Crop_화면 캡처 2024-07-22 152232.jpg
# Processed Noise_화면 캡처 2024-07-22 152232.jpg
# Processed Blur_화면 캡처 2024-07-22 152232.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152247.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152247.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152247.jpg
# Processed Rotate_화면 캡처 2024-07-22 152247.jpg
# Processed Brightness_화면 캡처 2024-07-22 152247.jpg
# Processed Contrast_화면 캡처 2024-07-22 152247.jpg
# Processed Saturation_화면 캡처 2024-07-22 152247.jpg
# Processed Crop_화면 캡처 2024-07-22 152247.jpg
# Processed Noise_화면 캡처 2024-07-22 152247.jpg
# Processed Blur_화면 캡처 2024-07-22 152247.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152259.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152259.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152259.jpg
# Processed Rotate_화면 캡처 2024-07-22 152259.jpg
# Processed Brightness_화면 캡처 2024-07-22 152259.jpg
# Processed Contrast_화면 캡처 2024-07-22 152259.jpg
# Processed Saturation_화면 캡처 2024-07-22 152259.jpg
# Processed Crop_화면 캡처 2024-07-22 152259.jpg
# Processed Noise_화면 캡처 2024-07-22 152259.jpg
# Processed Blur_화면 캡처 2024-07-22 152259.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152311.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152311.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152311.jpg
# Processed Rotate_화면 캡처 2024-07-22 152311.jpg
# Processed Brightness_화면 캡처 2024-07-22 152311.jpg
# Processed Contrast_화면 캡처 2024-07-22 152311.jpg
# Processed Saturation_화면 캡처 2024-07-22 152311.jpg
# Processed Crop_화면 캡처 2024-07-22 152311.jpg
# Processed Noise_화면 캡처 2024-07-22 152311.jpg
# Processed Blur_화면 캡처 2024-07-22 152311.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152322.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152322.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152322.jpg
# Processed Rotate_화면 캡처 2024-07-22 152322.jpg
# Processed Brightness_화면 캡처 2024-07-22 152322.jpg
# Processed Contrast_화면 캡처 2024-07-22 152322.jpg
# Processed Saturation_화면 캡처 2024-07-22 152322.jpg
# Processed Crop_화면 캡처 2024-07-22 152322.jpg
# Processed Noise_화면 캡처 2024-07-22 152322.jpg
# Processed Blur_화면 캡처 2024-07-22 152322.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152333.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152333.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152333.jpg
# Processed Rotate_화면 캡처 2024-07-22 152333.jpg
# Processed Brightness_화면 캡처 2024-07-22 152333.jpg
# Processed Contrast_화면 캡처 2024-07-22 152333.jpg
# Processed Saturation_화면 캡처 2024-07-22 152333.jpg
# Processed Crop_화면 캡처 2024-07-22 152333.jpg
# Processed Noise_화면 캡처 2024-07-22 152333.jpg
# Processed Blur_화면 캡처 2024-07-22 152333.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152345.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152345.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152345.jpg
# Processed Rotate_화면 캡처 2024-07-22 152345.jpg
# Processed Brightness_화면 캡처 2024-07-22 152345.jpg
# Processed Contrast_화면 캡처 2024-07-22 152345.jpg
# Processed Saturation_화면 캡처 2024-07-22 152345.jpg
# Processed Crop_화면 캡처 2024-07-22 152345.jpg
# Processed Noise_화면 캡처 2024-07-22 152345.jpg
# Processed Blur_화면 캡처 2024-07-22 152345.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152355.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152355.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152355.jpg
# Processed Rotate_화면 캡처 2024-07-22 152355.jpg
# Processed Brightness_화면 캡처 2024-07-22 152355.jpg
# Processed Contrast_화면 캡처 2024-07-22 152355.jpg
# Processed Saturation_화면 캡처 2024-07-22 152355.jpg
# Processed Crop_화면 캡처 2024-07-22 152355.jpg
# Processed Noise_화면 캡처 2024-07-22 152355.jpg
# Processed Blur_화면 캡처 2024-07-22 152355.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152408.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152408.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152408.jpg
# Processed Rotate_화면 캡처 2024-07-22 152408.jpg
# Processed Brightness_화면 캡처 2024-07-22 152408.jpg
# Processed Contrast_화면 캡처 2024-07-22 152408.jpg
# Processed Saturation_화면 캡처 2024-07-22 152408.jpg
# Processed Crop_화면 캡처 2024-07-22 152408.jpg
# Processed Noise_화면 캡처 2024-07-22 152408.jpg
# Processed Blur_화면 캡처 2024-07-22 152408.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152421.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152421.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152421.jpg
# Processed Rotate_화면 캡처 2024-07-22 152421.jpg
# Processed Brightness_화면 캡처 2024-07-22 152421.jpg
# Processed Contrast_화면 캡처 2024-07-22 152421.jpg
# Processed Saturation_화면 캡처 2024-07-22 152421.jpg
# Processed Crop_화면 캡처 2024-07-22 152421.jpg
# Processed Noise_화면 캡처 2024-07-22 152421.jpg
# Processed Blur_화면 캡처 2024-07-22 152421.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152432.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152432.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152432.jpg
# Processed Rotate_화면 캡처 2024-07-22 152432.jpg
# Processed Brightness_화면 캡처 2024-07-22 152432.jpg
# Processed Contrast_화면 캡처 2024-07-22 152432.jpg
# Processed Saturation_화면 캡처 2024-07-22 152432.jpg
# Processed Crop_화면 캡처 2024-07-22 152432.jpg
# Processed Noise_화면 캡처 2024-07-22 152432.jpg
# Processed Blur_화면 캡처 2024-07-22 152432.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152446.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152446.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152446.jpg
# Processed Rotate_화면 캡처 2024-07-22 152446.jpg
# Processed Brightness_화면 캡처 2024-07-22 152446.jpg
# Processed Contrast_화면 캡처 2024-07-22 152446.jpg
# Processed Saturation_화면 캡처 2024-07-22 152446.jpg
# Processed Crop_화면 캡처 2024-07-22 152446.jpg
# Processed Noise_화면 캡처 2024-07-22 152446.jpg
# Processed Blur_화면 캡처 2024-07-22 152446.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152457.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152457.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152457.jpg
# Processed Rotate_화면 캡처 2024-07-22 152457.jpg
# Processed Brightness_화면 캡처 2024-07-22 152457.jpg
# Processed Contrast_화면 캡처 2024-07-22 152457.jpg
# Processed Saturation_화면 캡처 2024-07-22 152457.jpg
# Processed Crop_화면 캡처 2024-07-22 152457.jpg
# Processed Noise_화면 캡처 2024-07-22 152457.jpg
# Processed Blur_화면 캡처 2024-07-22 152457.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152507.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152507.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152507.jpg
# Processed Rotate_화면 캡처 2024-07-22 152507.jpg
# Processed Brightness_화면 캡처 2024-07-22 152507.jpg
# Processed Contrast_화면 캡처 2024-07-22 152507.jpg
# Processed Saturation_화면 캡처 2024-07-22 152507.jpg
# Processed Crop_화면 캡처 2024-07-22 152507.jpg
# Processed Noise_화면 캡처 2024-07-22 152507.jpg
# Processed Blur_화면 캡처 2024-07-22 152507.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152518.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152518.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152518.jpg
# Processed Rotate_화면 캡처 2024-07-22 152518.jpg
# Processed Brightness_화면 캡처 2024-07-22 152518.jpg
# Processed Contrast_화면 캡처 2024-07-22 152518.jpg
# Processed Saturation_화면 캡처 2024-07-22 152518.jpg
# Processed Crop_화면 캡처 2024-07-22 152518.jpg
# Processed Noise_화면 캡처 2024-07-22 152518.jpg
# Processed Blur_화면 캡처 2024-07-22 152518.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152531.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152531.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152531.jpg
# Processed Rotate_화면 캡처 2024-07-22 152531.jpg
# Processed Brightness_화면 캡처 2024-07-22 152531.jpg
# Processed Contrast_화면 캡처 2024-07-22 152531.jpg
# Processed Saturation_화면 캡처 2024-07-22 152531.jpg
# Processed Crop_화면 캡처 2024-07-22 152531.jpg
# Processed Noise_화면 캡처 2024-07-22 152531.jpg
# Processed Blur_화면 캡처 2024-07-22 152531.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152542.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152542.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152542.jpg
# Processed Rotate_화면 캡처 2024-07-22 152542.jpg
# Processed Brightness_화면 캡처 2024-07-22 152542.jpg
# Processed Contrast_화면 캡처 2024-07-22 152542.jpg
# Processed Saturation_화면 캡처 2024-07-22 152542.jpg
# Processed Crop_화면 캡처 2024-07-22 152542.jpg
# Processed Noise_화면 캡처 2024-07-22 152542.jpg
# Processed Blur_화면 캡처 2024-07-22 152542.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152558.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152558.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152558.jpg
# Processed Rotate_화면 캡처 2024-07-22 152558.jpg
# Processed Brightness_화면 캡처 2024-07-22 152558.jpg
# Processed Contrast_화면 캡처 2024-07-22 152558.jpg
# Processed Saturation_화면 캡처 2024-07-22 152558.jpg
# Processed Crop_화면 캡처 2024-07-22 152558.jpg
# Processed Noise_화면 캡처 2024-07-22 152558.jpg
# Processed Blur_화면 캡처 2024-07-22 152558.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152608.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152608.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152608.jpg
# Processed Rotate_화면 캡처 2024-07-22 152608.jpg
# Processed Brightness_화면 캡처 2024-07-22 152608.jpg
# Processed Contrast_화면 캡처 2024-07-22 152608.jpg
# Processed Saturation_화면 캡처 2024-07-22 152608.jpg
# Processed Crop_화면 캡처 2024-07-22 152608.jpg
# Processed Noise_화면 캡처 2024-07-22 152608.jpg
# Processed Blur_화면 캡처 2024-07-22 152608.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152618.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152618.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152618.jpg
# Processed Rotate_화면 캡처 2024-07-22 152618.jpg
# Processed Brightness_화면 캡처 2024-07-22 152618.jpg
# Processed Contrast_화면 캡처 2024-07-22 152618.jpg
# Processed Saturation_화면 캡처 2024-07-22 152618.jpg
# Processed Crop_화면 캡처 2024-07-22 152618.jpg
# Processed Noise_화면 캡처 2024-07-22 152618.jpg
# Processed Blur_화면 캡처 2024-07-22 152618.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152628.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152628.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152628.jpg
# Processed Rotate_화면 캡처 2024-07-22 152628.jpg
# Processed Brightness_화면 캡처 2024-07-22 152628.jpg
# Processed Contrast_화면 캡처 2024-07-22 152628.jpg
# Processed Saturation_화면 캡처 2024-07-22 152628.jpg
# Processed Crop_화면 캡처 2024-07-22 152628.jpg
# Processed Noise_화면 캡처 2024-07-22 152628.jpg
# Processed Blur_화면 캡처 2024-07-22 152628.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152639.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152639.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152639.jpg
# Processed Rotate_화면 캡처 2024-07-22 152639.jpg
# Processed Brightness_화면 캡처 2024-07-22 152639.jpg
# Processed Contrast_화면 캡처 2024-07-22 152639.jpg
# Processed Saturation_화면 캡처 2024-07-22 152639.jpg
# Processed Crop_화면 캡처 2024-07-22 152639.jpg
# Processed Noise_화면 캡처 2024-07-22 152639.jpg
# Processed Blur_화면 캡처 2024-07-22 152639.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152648.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152648.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152648.jpg
# Processed Rotate_화면 캡처 2024-07-22 152648.jpg
# Processed Brightness_화면 캡처 2024-07-22 152648.jpg
# Processed Contrast_화면 캡처 2024-07-22 152648.jpg
# Processed Saturation_화면 캡처 2024-07-22 152648.jpg
# Processed Crop_화면 캡처 2024-07-22 152648.jpg
# Processed Noise_화면 캡처 2024-07-22 152648.jpg
# Processed Blur_화면 캡처 2024-07-22 152648.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152703.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152703.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152703.jpg
# Processed Rotate_화면 캡처 2024-07-22 152703.jpg
# Processed Brightness_화면 캡처 2024-07-22 152703.jpg
# Processed Contrast_화면 캡처 2024-07-22 152703.jpg
# Processed Saturation_화면 캡처 2024-07-22 152703.jpg
# Processed Crop_화면 캡처 2024-07-22 152703.jpg
# Processed Noise_화면 캡처 2024-07-22 152703.jpg
# Processed Blur_화면 캡처 2024-07-22 152703.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152713.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152713.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152713.jpg
# Processed Rotate_화면 캡처 2024-07-22 152713.jpg
# Processed Brightness_화면 캡처 2024-07-22 152713.jpg
# Processed Contrast_화면 캡처 2024-07-22 152713.jpg
# Processed Saturation_화면 캡처 2024-07-22 152713.jpg
# Processed Crop_화면 캡처 2024-07-22 152713.jpg
# Processed Noise_화면 캡처 2024-07-22 152713.jpg
# Processed Blur_화면 캡처 2024-07-22 152713.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152724.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152724.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152724.jpg
# Processed Rotate_화면 캡처 2024-07-22 152724.jpg
# Processed Brightness_화면 캡처 2024-07-22 152724.jpg
# Processed Contrast_화면 캡처 2024-07-22 152724.jpg
# Processed Saturation_화면 캡처 2024-07-22 152724.jpg
# Processed Crop_화면 캡처 2024-07-22 152724.jpg
# Processed Noise_화면 캡처 2024-07-22 152724.jpg
# Processed Blur_화면 캡처 2024-07-22 152724.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152735.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152735.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152735.jpg
# Processed Rotate_화면 캡처 2024-07-22 152735.jpg
# Processed Brightness_화면 캡처 2024-07-22 152735.jpg
# Processed Contrast_화면 캡처 2024-07-22 152735.jpg
# Processed Saturation_화면 캡처 2024-07-22 152735.jpg
# Processed Crop_화면 캡처 2024-07-22 152735.jpg
# Processed Noise_화면 캡처 2024-07-22 152735.jpg
# Processed Blur_화면 캡처 2024-07-22 152735.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152745.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152745.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152745.jpg
# Processed Rotate_화면 캡처 2024-07-22 152745.jpg
# Processed Brightness_화면 캡처 2024-07-22 152745.jpg
# Processed Contrast_화면 캡처 2024-07-22 152745.jpg
# Processed Saturation_화면 캡처 2024-07-22 152745.jpg
# Processed Crop_화면 캡처 2024-07-22 152745.jpg
# Processed Noise_화면 캡처 2024-07-22 152745.jpg
# Processed Blur_화면 캡처 2024-07-22 152745.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152758.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152758.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152758.jpg
# Processed Rotate_화면 캡처 2024-07-22 152758.jpg
# Processed Brightness_화면 캡처 2024-07-22 152758.jpg
# Processed Contrast_화면 캡처 2024-07-22 152758.jpg
# Processed Saturation_화면 캡처 2024-07-22 152758.jpg
# Processed Crop_화면 캡처 2024-07-22 152758.jpg
# Processed Noise_화면 캡처 2024-07-22 152758.jpg
# Processed Blur_화면 캡처 2024-07-22 152758.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152808.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152808.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152808.jpg
# Processed Rotate_화면 캡처 2024-07-22 152808.jpg
# Processed Brightness_화면 캡처 2024-07-22 152808.jpg
# Processed Contrast_화면 캡처 2024-07-22 152808.jpg
# Processed Saturation_화면 캡처 2024-07-22 152808.jpg
# Processed Crop_화면 캡처 2024-07-22 152808.jpg
# Processed Noise_화면 캡처 2024-07-22 152808.jpg
# Processed Blur_화면 캡처 2024-07-22 152808.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152820.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152820.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152820.jpg
# Processed Rotate_화면 캡처 2024-07-22 152820.jpg
# Processed Brightness_화면 캡처 2024-07-22 152820.jpg
# Processed Contrast_화면 캡처 2024-07-22 152820.jpg
# Processed Saturation_화면 캡처 2024-07-22 152820.jpg
# Processed Crop_화면 캡처 2024-07-22 152820.jpg
# Processed Noise_화면 캡처 2024-07-22 152820.jpg
# Processed Blur_화면 캡처 2024-07-22 152820.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152829.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152829.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152829.jpg
# Processed Rotate_화면 캡처 2024-07-22 152829.jpg
# Processed Brightness_화면 캡처 2024-07-22 152829.jpg
# Processed Contrast_화면 캡처 2024-07-22 152829.jpg
# Processed Saturation_화면 캡처 2024-07-22 152829.jpg
# Processed Crop_화면 캡처 2024-07-22 152829.jpg
# Processed Noise_화면 캡처 2024-07-22 152829.jpg
# Processed Blur_화면 캡처 2024-07-22 152829.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152839.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152839.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152839.jpg
# Processed Rotate_화면 캡처 2024-07-22 152839.jpg
# Processed Brightness_화면 캡처 2024-07-22 152839.jpg
# Processed Contrast_화면 캡처 2024-07-22 152839.jpg
# Processed Saturation_화면 캡처 2024-07-22 152839.jpg
# Processed Crop_화면 캡처 2024-07-22 152839.jpg
# Processed Noise_화면 캡처 2024-07-22 152839.jpg
# Processed Blur_화면 캡처 2024-07-22 152839.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152848.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152848.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152848.jpg
# Processed Rotate_화면 캡처 2024-07-22 152848.jpg
# Processed Brightness_화면 캡처 2024-07-22 152848.jpg
# Processed Contrast_화면 캡처 2024-07-22 152848.jpg
# Processed Saturation_화면 캡처 2024-07-22 152848.jpg
# Processed Crop_화면 캡처 2024-07-22 152848.jpg
# Processed Noise_화면 캡처 2024-07-22 152848.jpg
# Processed Blur_화면 캡처 2024-07-22 152848.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152859.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152859.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152859.jpg
# Processed Rotate_화면 캡처 2024-07-22 152859.jpg
# Processed Brightness_화면 캡처 2024-07-22 152859.jpg
# Processed Contrast_화면 캡처 2024-07-22 152859.jpg
# Processed Saturation_화면 캡처 2024-07-22 152859.jpg
# Processed Crop_화면 캡처 2024-07-22 152859.jpg
# Processed Noise_화면 캡처 2024-07-22 152859.jpg
# Processed Blur_화면 캡처 2024-07-22 152859.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152908.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152908.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152908.jpg
# Processed Rotate_화면 캡처 2024-07-22 152908.jpg
# Processed Brightness_화면 캡처 2024-07-22 152908.jpg
# Processed Contrast_화면 캡처 2024-07-22 152908.jpg
# Processed Saturation_화면 캡처 2024-07-22 152908.jpg
# Processed Crop_화면 캡처 2024-07-22 152908.jpg
# Processed Noise_화면 캡처 2024-07-22 152908.jpg
# Processed Blur_화면 캡처 2024-07-22 152908.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152918.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152918.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152918.jpg
# Processed Rotate_화면 캡처 2024-07-22 152918.jpg
# Processed Brightness_화면 캡처 2024-07-22 152918.jpg
# Processed Contrast_화면 캡처 2024-07-22 152918.jpg
# Processed Saturation_화면 캡처 2024-07-22 152918.jpg
# Processed Crop_화면 캡처 2024-07-22 152918.jpg
# Processed Noise_화면 캡처 2024-07-22 152918.jpg
# Processed Blur_화면 캡처 2024-07-22 152918.jpg
# Processed GreenBlend_화면 캡처 2024-07-22 152929.jpg
# Processed FlipLR_화면 캡처 2024-07-22 152929.jpg
# Processed FlipTB_화면 캡처 2024-07-22 152929.jpg
# Processed Rotate_화면 캡처 2024-07-22 152929.jpg
# Processed Brightness_화면 캡처 2024-07-22 152929.jpg
# Processed Contrast_화면 캡처 2024-07-22 152929.jpg
# Processed Saturation_화면 캡처 2024-07-22 152929.jpg
# Processed Crop_화면 캡처 2024-07-22 152929.jpg
# Processed Noise_화면 캡처 2024-07-22 152929.jpg
# Processed Blur_화면 캡처 2024-07-22 152929.jpg
